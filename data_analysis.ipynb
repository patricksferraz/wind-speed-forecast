# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
def show_all(dataframe, index):
    nans = np.where(np.isnan(dataframe.values))
    print(
        "\nColumn {}\nMax {}\nMédia {}\nMediana {}\nMínimo {}\nNan {}".format(
            index,
            dataframe.max(),
            dataframe.mean(),
            dataframe.median(),
            dataframe.min(),
            np.where(np.isnan(dataframe.values))
            # dataframe.mode(),
        )
    )
    return nans

# %%
dataframe = pd.read_csv(
    "confidential/train150.txt", delimiter="\t", header=None
)
dataset = dataframe.values

# %%
print("[INFO] Dataframe info")
dataframe.info()
# Out:
# [INFO] Dataframe info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 9 columns):
# 0    550 non-null int64
# 1    550 non-null int64
# 2    550 non-null int64
# 3    550 non-null int64
# 4    550 non-null float64
# 5    550 non-null float64
# 6    550 non-null float64
# 7    550 non-null float64
# 8    550 non-null float64
# dtypes: float64(5), int64(4)
# memory usage: 38.8 KB

# %%
print("[INFO] Columns info")
nans_4 = show_all(dataframe[4], 4)
nans_5 = show_all(dataframe[5], 5)
nans_6 = show_all(dataframe[6], 6)
nans_7 = show_all(dataframe[7], 7)
nans_8 = show_all(dataframe[8], 8)
# Out:
# [INFO] Columns info
#
# Column 4
# Max 13.57222223
# Média 8.176718634154545
# Mediana 8.320000021
# Mínimo 1.211904759
# Nan (array([], dtype=int64),)
#
# Column 5
# Max 356.553715
# Média 73.02764740522183
# Mediana 59.019306785
# Mínimo 1.4481789669999998
# Nan (array([], dtype=int64),)
#
# Column 6
# Max 30.140625
# Média 24.4430172462
# Mediana 24.33473389
# Mínimo 20.61627907
# Nan (array([], dtype=int64),)
#
# Column 7
# Max 98.0
# Média 85.26357832403636
# Mediana 86.7658046
# Mínimo 46.35555556
# Nan (array([], dtype=int64),)
#
# Column 8
# Max 1023.7265
# Média 1017.3139859783637
# Mediana 1020.04675
# Mínimo 937.5343332999998
# Nan (array([], dtype=int64),)

# %%
# plt.style.use("ggplot")
# _, axs = plt.subplots(3, 2)
# axs[0][0].plot(range(0, len(dataset[:, 3])), dataset[:, 4])
# axs[0][0].set_title("velo")
# axs[1][0].plot(range(0, len(dataset[:, 3])), dataset[:, 5])
# axs[1][0].set_title("dir")
# axs[2][0].plot(range(0, len(dataset[:, 3])), dataset[:, 6])
# axs[2][0].set_title("temp")
# axs[1][1].plot(range(0, len(dataset[:, 3])), dataset[:, 7])
# axs[1][1].set_title("umi")
# axs[2][1].plot(range(0, len(dataset[:, 3])), dataset[:, 8])
# axs[2][1].set_title("press")
# plt.legend()
# plt.show()

# %%
plt.style.use("ggplot")
plt.plot(range(0, len(dataset[:, 3])), dataset[:, 4], label="velocidade")
plt.legend()
plt.show()
plt.plot(range(0, len(dataset[:, 3])), dataset[:, 5], label="direção")
plt.legend()
plt.show()
plt.plot(range(0, len(dataset[:, 3])), dataset[:, 6], label="temperatura")
plt.legend()
plt.show()
plt.plot(range(0, len(dataset[:, 3])), dataset[:, 7], label="umidade")
plt.legend()
plt.show()
plt.plot(range(0, len(dataset[:, 3])), dataset[:, 8], label="pressão")
plt.legend()
plt.show()
